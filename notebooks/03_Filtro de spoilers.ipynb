# %% [markdown]
# # 3. Filtro de spoilers
# ### Dada la siguiente reseña de una película:

# %% [markdown]
# Solicite al usuario una lista de palabras consideradas spoilers (separadas por
# coma). El programa debe reemplazar todas las apariciones de esas palabras en el
# texto por asteriscos (*) de la misma longitud, sin distinguir mayúsculas de
# minúsculas.
#
# ### Ejemplo de entrada y salida esperada:
# Ingrese las palabras spoiler (separadas por coma): Marte, Torres, sacrificio
#
# La película sigue a un grupo de astronautas que viajan a *****
# en una misión de rescate. El capitán ****** lidera al equipo a través
# de tormentas solares y fallos en el sistema de navegación. Al llegar
# a ***** descubren que la base está abandonada y los suministros
# destruidos. ****** decide ********** la nave nodriza para salvar
# al equipo y logran volver a la Tierra en una cápsula de emergencia.
# El final revela que ****** ********** gracias a un pasaje secreto.

# %% [markdown]
# # CÓDIGO

# %%
import re

review = """La película sigue a un grupo de astronautas que 
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo 
a través
de tormentas solares y fallos en el sistema de navegación. Al 
llegar
a Marte descubren que la base está abandonada y los 
suministros
destruidos. Torres decide sacrificar la nave nodriza para 
salvar
al equipo y logran volver a la Tierra en una cápsula de 
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje 
secreto."""

spoilers = input('Ingrese las palabras spoiler (separadas por coma): Marte, Torres, sacrificio ')
spoilers_list =  spoilers.split(',')

      
for spoiler in spoilers_list:
    spoiler = spoiler.strip()
    asteriscos = '*' * len(spoiler)
    review = re.sub(r'\b' + spoiler + r'\b', asteriscos, review, flags=re.IGNORECASE)


print(f'Los spoilers elegidos por el usuario son: {spoilers}')
print(review)
# Out:
# Ingrese las palabras spoiler (separadas por coma): Marte, Torres, sacrificio  lA, película, sigue
# Los spoilers elegidos por el usuario son: lA, película, sigue
# ** ******** ***** a un grupo de astronautas que
# viajan a Marte
# en una misión de rescate. El capitán Torres lidera al equipo
# a través
# de tormentas solares y fallos en el sistema de navegación. Al
# llegar
# a Marte descubren que ** base está abandonada y los
# suministros
# destruidos. Torres decide sacrificar ** nave nodriza para
# salvar
# al equipo y logran volver a ** Tierra en una cápsula de
# emergencia.
# El final revela que Torres sobrevivió gracias a un pasaje
# secreto.
