# %% [markdown]
# ### Valide una dirección de email ingresada por el usuario con los siguientes
# ### criterios:
# ### • Contiene exactamente un @.
# ### • Tiene al menos un carácter antes del @.
# ### • Tiene al menos un punto (.) después del @.
# ### • No empieza ni termina con @ ni con ..
# ### • La parte después del último punto tiene al menos 2 caracteres (el dominio).
# ### Ejemplo de entrada y salida esperada:
# ### Ingrese un email: usuario@ejemplo.com
# ### El email es válido.
# ### Ingrese un email: @ejemplo.com
# ### El email no es válido.
# ### Ingrese un email: usuario@ejemplo
# ### El email no es válido.

# %%
import sys
sys.path.append('../src')
from validation_email import  validar_email

email_input = input('Ingrese su email')


if validar_email(email_input):
    print('El email es válido.')
else:
    print('El email no es válido.')
# Out:
# Ingrese su email leanfreestyle9@gmail.com
# El email es válido.
